# %%
from __future__ import annotations

import sys
from pathlib import Path
import argparse
import pandas as pd
from joblib import load

# === ADD PROJECT ROOT TO PATH ===
PROJECT_ROOT = Path("/Users/sarahilyas/Life_Expectancy_Regression")
sys.path.append(str(PROJECT_ROOT))
print("📂 Project root added:", PROJECT_ROOT)

# === CORRECT IMPORT ===
from Life_Expectancy_Regression.src.Feature_Pipeline.feature_engineering import (
    drop_state,
    select_top_features,
    freq_encode_state,
)
# Out:
# 📂 Project root added: /Users/sarahilyas/Life_Expectancy_Regression
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[81], line 15
#      12 print("📂 Project root added:", PROJECT_ROOT)
#      14 # === CORRECT IMPORT ===
# ---> 15 from Life_Expectancy_Regression.src.Feature_Pipeline.feature_engineering import (
#      16     drop_state,
#      17     select_top_features,
#      18     freq_encode_state,
#      19 )
#
# ImportError: cannot import name 'drop_state' from 'Life_Expectancy_Regression.src.Feature_Pipeline.feature_engineering' (/Users/sarahilyas/Life_Expectancy_Regression/src/Feature_Pipeline/feature_engineering.py)

# %%
from __future__ import annotations

import sys
from pathlib import Path
import argparse
import pandas as pd
from joblib import load

# === ADD PROJECT ROOT TO PATH ===
PROJECT_ROOT = Path("/Users/sarahilyas/Life_Expectancy_Regression")
sys.path.append(str(PROJECT_ROOT))
print("📂 Project root added:", PROJECT_ROOT)

# === CORRECT IMPORT FOR THIS PATH SETUP ===
from src.Feature_Pipeline.feature_engineering import (
    drop_state,
    select_top_features,
    freq_encode_state,
)
# Out:
# 📂 Project root added: /Users/sarahilyas/Life_Expectancy_Regression
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[79], line 15
#      12 print("📂 Project root added:", PROJECT_ROOT)
#      14 # === CORRECT IMPORT FOR THIS PATH SETUP ===
# ---> 15 from src.Feature_Pipeline.feature_engineering import (
#      16     drop_state,
#      17     select_top_features,
#      18     freq_encode_state,
#      19 )
#
# ImportError: cannot import name 'drop_state' from 'src.Feature_Pipeline.feature_engineering' (/Users/sarahilyas/Life_Expectancy_Regression/src/Feature_Pipeline/feature_engineering.py)
